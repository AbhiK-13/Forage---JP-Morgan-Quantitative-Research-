# %%
import pandas as pd 
import matplotlib.pyplot as plt 
from sklearn.tree import DecisionTreeClassifier # Import Decision Tree Classifier
from sklearn.model_selection import train_test_split # Import train_test_split function
from sklearn import metrics #Import scikit-learn metrics module for accuracy calculation

# %%
loandata = pd.read_csv("C:/Users/abhik/OneDrive/Desktop/Coding stuff/Python/Forage - Quant Research/Task 3 and 4_Loan_Data.csv")

loandata.head()
# Out:
#    customer_id  credit_lines_outstanding  loan_amt_outstanding  \
# 0      8153374                         0           5221.545193
# 1      7442532                         5           1958.928726
# 2      2256073                         0           3363.009259
# 3      4885975                         0           4766.648001
# 4      4700614                         1           1345.827718
#
#    total_debt_outstanding       income  years_employed  fico_score  default
# 0             3915.471226  78039.38546               5         605        0
# 1             8228.752520  26648.43525               2         572        1
# 2             2027.830850  65866.71246               4         602        0
# 3             2501.730397  74356.88347               5         612        0
# 4             1768.826187  23448.32631               6         631        0

# %%
# Splitting dataset into feature and target variables: 

feature_cols = ['credit_lines_outstanding', 'loan_amt_outstanding', 'total_debt_outstanding', 'income', 'fico_score']
X = loandata[feature_cols]
y = loandata['default']

# %%
# Splitting dataset into trian and test data: 
 
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1) # 70% training and 30% test

# %%
# Building a Decision Tree Model: 

clf = DecisionTreeClassifier()
clf = clf.fit(X_train, y_train)
    # The above code is for training the classifier 

y_pred = clf.predict(X_test)
    # This code is for predicting the response for the test dataset

# %%
# Evaluating the model: 

print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# The accuracy is aorund 98%, which could be a downside as it could indicate strong model overfitting
# Out:
# Accuracy: 0.9766666666666667
